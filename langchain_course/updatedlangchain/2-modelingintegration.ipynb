# %% [markdown]
# ### Models Integration with OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]= os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.0', 'langchain': '1.3.16', 'langchain-openai': '1.6.0'}}, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x0000018D41120C10>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000018D41120290>, root_client=<openai.OpenAI object at 0x0000018D41120E50>, root_async_client=<openai.AsyncOpenAI object at 0x0000018D411206D0>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
## invoke the model
response = model.invoke("Hello, How are you?")
response
# Out:
# AIMessage(content="Hello! I'm just a virtual assistant, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 13, 'total_tokens': 43, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_96322fb694', 'id': 'chatcmpl-EGAst00RvqNElvDRfDBMRfeMcX5du', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a030b8-81af-7ed3-9296-d5e022a39902-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 30, 'total_tokens': 43, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
response.content
# Out:
# "Hello! I'm just a virtual assistant, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?"

# %%
### ChatOpenAI 

from langchain_openai import ChatOpenAI 
ChatOpenAI(model="gpt4.1")
response = model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': "Hello! I'm doing well, thank you for asking. How can I help you today?", 'extras': {'signature': 'El4KXAERTTIP1/ger2bdlbEdYQpJaqoZ9aiOoK8riDqY1exQlpgZ+x3XcDRJAWo93Vw/vySpokdoJtvFCrisj50noA6zsjQ+KhWUgTO1Kqi4wkcxBWxjYDLWcXzp1fr8'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a030d1-6251-7181-b321-79a20edaead3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 20, 'total_tokens': 26, 'input_token_details': {'cache_read': 0}})

# %%
### Google Gemini Models Integration

from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-3.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Parrots talk because of a fascinating combination of **anatomy, social behavior, and high intelligence**. Unlike humans, parrots don’t have vocal cords; instead, they use a specialized organ called the **syrinx** to produce sounds. \n\nHere is a breakdown of the main reasons why parrots talk:\n\n### 1. They are Hardwired for Social Integration (Flock Mentality)\nIn the wild, parrots are extremely social flock animals. To survive, individuals must fit in with the group. They do this by mimicking the calls of their flockmates. \n* When a parrot is kept as a pet, **its human family becomes its flock**. \n* Talking is a way for the parrot to bond, communicate, and feel like a part of the "flock."\n\n### 2. Desire for Attention and Interaction\nParrots quickly learn that human speech gets a reaction. If a parrot says "Hello!" or mimics the microwave, and a human comes running, laughs, or gives them attention, the parrot learns that **talking is a powerful tool to get what they want**. Even negative reactions (like yelling "Quiet!") can reinforce the behavior because the bird still got attention.\n\n### 3. High Intelligence and Boredom\nParrots possess the cognitive intelligence of a human toddler (and sometimes higher, in the case of African Greys). They have massive brains relative to their size and need mental stimulation. Mimicking human speech is a fun puzzle and a way to entertain themselves when they are bored.\n\n### 4. Environmental Triggering and Association\nParrots associate certain words with specific events or routines. \n* They might yell "Bye-bye!" because they notice you putting on shoes.\n* They might say "Uh-oh" whenever something is dropped because they hear humans say it in that exact context. \n* They often aren\'t just repeating sounds blindly; they often understand the *context* in which the words are used.\n\n### 5. Territorial and Mating Calls\nIn the wild, vocal learning is used to establish territory and attract mates. Domestic parrots may use learned human phrases to assert dominance over a room, express excitement, or claim a favorite human.\n\n---\n\n### A Fun Fact: Do they know what they are saying?\nWhile many parrots just mimic sounds without understanding them, some—most famously an African Grey parrot named **Alex**, studied by Dr. Irene Pepperberg—demonstrated the ability to use human words meaningfully. Alex could identify colors, shapes, and numbers, proving that parrots are capable of true, intentional communication using human language.', 'extras': {'signature': 'El4KXAERTTIPFod9nn2cridtrP8RX6sFUEx2rAJFj3kEdlSmaGh7QWgOamkX/uL+FM9MIZgU/g786MgiIroCSZEzJrXdWhYykE53CtAtgh9E48lQb8j8A9xPzKilrBCp'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a030cd-6a2e-7041-9882-77a78d05bd4a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 533, 'total_tokens': 539, 'input_token_details': {'cache_read': 0}})

# %%
from langchain_google_genai import ChatGoogleGenerativeAI 

model = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
response = model.invoke("Why do Chinese have every possible words in their native langauge?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The perception that the Chinese language has "every possible word" comes from a combination of how the language is structured, its massive historical vocabulary, and how easily it creates new words. \n\nHowever, linguistically speaking, **no language has *every* possible word**, and every language has gaps (concepts that require multiple words or translation in another language). \n\nThat said, Chinese has unique characteristics that make its vocabulary feel vast, precise, and infinitely expandable. Here is why:\n\n### 1. The "Lego" Nature of Chinese Words\nUnlike English, which often invents entirely new root words from Latin or Greek for new concepts (e.g., *telephone*, *television*, *automobile*), Chinese creates words by combining existing characters like building blocks. \n* **Computer** in Chinese is 电脑 (*diànnǎo*), which literally means **"electric brain."**\n* **Train** is 火车 (*huǒchē*), meaning **"fire-cart."**\n* **Airplane** is 飞机 (*fēijī*), meaning **"flying machine."**\n\nBecause of this, Chinese can easily coin a word for *any* new modern invention or abstract concept instantly using existing vocabulary. \n\n### 2. Over 3,000 Years of Written History\nChinese is one of the oldest continuously used written languages in the world. For millennia, scholars, poets, and philosophers have coined terms for every human emotion, natural phenomenon, social relation, and strategy. Classical Chinese literature contains an enormous treasure trove of idioms (*chengyu*), poetic descriptions, and specific nouns that have accumulated over thousands of years.\n\n### 3. Extreme Nuance and Specificity\nChinese often has words for very specific situations that require whole sentences in English. For example:\n* **"Jiāyóu" (加油):** Literally "add oil," but it means keep going, don\'t give up, I support you, step on the gas—all in one context.\n* **Kinship terms:** English uses "uncle" for your mother\'s brother, father\'s brother, and mother\'s/father\'s sister\'s husband. Chinese has a completely different, highly specific word for *each* of them based on whether they are older or younger than your parent, and on which side of the family they are on. \n\n### 4. High-Context Idioms (*Chengyu*)\nMost Chinese idioms are four characters long, but they pack an entire historical story, moral lesson, or complex emotional state into those four syllables. A single *chengyu* can express a concept that might take a paragraph to explain in English.\n\n### 5. Confirmation Bias\nWhen foreigners learn Chinese, they often encounter words that capture a very specific human experience they’ve felt before but never had a single word for. This creates the impression that Chinese has a word for *everything*. (To be fair, other languages do this too—like the German *Schadenfreude* or the Portuguese *Saudade*).\n\n### Summary\nChinese doesn’t literally have *every* word—for instance, it borrows phonetic loanwords for things that don\'t translate easily (like <b>Sī mǎ gé</b> for "Smog" or <b>Shāfas</b> for "Sofa"), and just like any language, it struggles to capture certain alien cultural concepts. \n\nHowever, because of its **combinatorial nature** (using basic characters to build infinite compounds) and its **deep historical roots**, it has an exceptional ability to name, describe, and encapsulate virtually any idea imaginable.', 'extras': {'signature': 'El4KXAERTTIPI19RkRcZC3PQGwUU2j4Pon8z2UVF4vj9dxkDaD4zpkgfxB2SDFUN7ZsOlKBaau6/bD5XP6wJhTpTXpI8J/FwTOMq0Gc4uTw/a0gdqjIAu2HEgaKJ/hbj'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a030d5-36a5-7ae3-adb2-8232ffb0276a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 754, 'total_tokens': 768, 'input_token_details': {'cache_read': 0}})

# %%
###GROQ Model Integrations

from langchain.chat_models import init_chat_model 

model = init_chat_model("groq:qwen/qwen3.6-27b")
response = model.invoke("Why do fireflies light up?")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Question**: The user asks "Why do fireflies light up?" This is a straightforward biology/nature question about the purpose/function of bioluminescence in fireflies.\n\n2.  **Identify Key Concepts**: \n   - Fireflies (lightning bugs) are beetles in the family Lampyridae\n   - They produce light through bioluminescence\n   - The primary reasons are communication, specifically mating\n   - Other reasons include warning predators (aposematism), attracting prey (in some species), and possibly illumination for foraging\n   - The chemical process involves luciferin, luciferase, ATP, oxygen, and magnesium ions\n\n3.  **Structure the Answer**:\n   - Direct answer first: Main purpose is communication/mating\n   - Explain the biological mechanism briefly (optional but helpful)\n   - List other functions\n   - Keep it clear, accurate, and concise\n\n4.  **Draft - Mental Refinement**:\n   Fireflies light up primarily to communicate, especially for mating. Each species has a unique flashing pattern that helps males and females find and recognize each other in the dark. The light is produced through a chemical reaction in their abdomen involving a molecule called luciferin, an enzyme called luciferase, oxygen, and ATP. \n\n   Beyond mating, the light serves other purposes:\n   - **Warning predators**: Fireflies are toxic, and their glow acts as a warning signal (aposematism) that they taste bad or are poisonous.\n   - **Attracting prey**: Some female fireflies (like the predatory *Photuris* species) mimic other species\' flashes to lure males, which they then eat.\n   - **Synchronization**: In some populations, males flash in unison to increase visibility and mating success.\n\n   The light is remarkably efficient—almost 100% of the energy becomes light with very little heat, which is why it\'s called "cold light."\n\n5.  **Check Accuracy**:\n   - Mating communication: ✓ (well-documented)\n   - Chemical process: luciferin + luciferase + O2 + ATP → light ✓\n   - Aposematism/toxicity: ✓ (fireflies contain lucibufagins, toxic compounds)\n   - Aggressive mimicry: ✓ (*Photuris* females mimic other species)\n   - Synchronization: ✓ (observed in Southeast Asia and US Southeast)\n   - "Cold light" efficiency: ✓ (~95-100% efficient vs incandescent ~10%)\n   - All facts are scientifically accurate and up-to-date.\n\n6.  **Final Polish**: Make it clear, engaging, and well-structured for a general audience. Avoid jargon where possible, explain necessary terms. Keep it concise.\n\n   Structure:\n   - Main reason (mating)\n   - How it works (briefly)\n   - Other reasons\n   - Fun/interesting fact (efficiency)\n   - Concluding sentence\n\n   All matches the draft. Ready.✅\n</think>\n\nFireflies light up primarily to **communicate**, especially for **mating**. Each species has a unique flashing pattern that allows males and females to recognize and locate one another in the dark. \n\nHere\'s a quick breakdown of why and how they do it:\n\n🔹 **Mating Signals**: Males fly around flashing species-specific patterns. Females, usually perched on vegetation, respond with timed flashes. This "flash dialogue" ensures they find the right mate.\n\n🔹 **Warning Predators**: Fireflies contain bitter, toxic chemicals called lucibufagins. Their glow acts as a visual warning (aposematism) to birds, frogs, and spiders: "I\'m poisonous, don\'t eat me."\n\n🔹 **Hunting (in some species)**: Certain female fireflies (like those in the genus *Photuris*) mimic the flash patterns of other species to lure males in, then eat them. This is called aggressive mimicry.\n\n🔹 **Synchronization**: In some regions (like parts of Southeast Asia and the southeastern US), large groups of fireflies flash in unison. This likely makes males more visible to females and reduces confusion from overlapping signals.\n\n💡 **How it works**: The light comes from a chemical reaction in specialized cells in their abdomen. A mo ...

# %%
response.content
# Out:
# '\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Question**: The user asks "Why do fireflies light up?" This is a straightforward biology/nature question about the purpose/function of bioluminescence in fireflies.\n\n2.  **Identify Key Concepts**: \n   - Fireflies (lightning bugs) are beetles in the family Lampyridae\n   - They produce light through bioluminescence\n   - The primary reasons are communication, specifically mating\n   - Other reasons include warning predators (aposematism), attracting prey (in some species), and possibly illumination for foraging\n   - The chemical process involves luciferin, luciferase, ATP, oxygen, and magnesium ions\n\n3.  **Structure the Answer**:\n   - Direct answer first: Main purpose is communication/mating\n   - Explain the biological mechanism briefly (optional but helpful)\n   - List other functions\n   - Keep it clear, accurate, and concise\n\n4.  **Draft - Mental Refinement**:\n   Fireflies light up primarily to communicate, especially for mating. Each species has a unique flashing pattern that helps males and females find and recognize each other in the dark. The light is produced through a chemical reaction in their abdomen involving a molecule called luciferin, an enzyme called luciferase, oxygen, and ATP. \n\n   Beyond mating, the light serves other purposes:\n   - **Warning predators**: Fireflies are toxic, and their glow acts as a warning signal (aposematism) that they taste bad or are poisonous.\n   - **Attracting prey**: Some female fireflies (like the predatory *Photuris* species) mimic other species\' flashes to lure males, which they then eat.\n   - **Synchronization**: In some populations, males flash in unison to increase visibility and mating success.\n\n   The light is remarkably efficient—almost 100% of the energy becomes light with very little heat, which is why it\'s called "cold light."\n\n5.  **Check Accuracy**:\n   - Mating communication: ✓ (well-documented)\n   - Chemical process: luciferin + luciferase + O2 + ATP → light ✓\n   - Aposematism/toxicity: ✓ (fireflies contain lucibufagins, toxic compounds)\n   - Aggressive mimicry: ✓ (*Photuris* females mimic other species)\n   - Synchronization: ✓ (observed in Southeast Asia and US Southeast)\n   - "Cold light" efficiency: ✓ (~95-100% efficient vs incandescent ~10%)\n   - All facts are scientifically accurate and up-to-date.\n\n6.  **Final Polish**: Make it clear, engaging, and well-structured for a general audience. Avoid jargon where possible, explain necessary terms. Keep it concise.\n\n   Structure:\n   - Main reason (mating)\n   - How it works (briefly)\n   - Other reasons\n   - Fun/interesting fact (efficiency)\n   - Concluding sentence\n\n   All matches the draft. Ready.✅\n</think>\n\nFireflies light up primarily to **communicate**, especially for **mating**. Each species has a unique flashing pattern that allows males and females to recognize and locate one another in the dark. \n\nHere\'s a quick breakdown of why and how they do it:\n\n🔹 **Mating Signals**: Males fly around flashing species-specific patterns. Females, usually perched on vegetation, respond with timed flashes. This "flash dialogue" ensures they find the right mate.\n\n🔹 **Warning Predators**: Fireflies contain bitter, toxic chemicals called lucibufagins. Their glow acts as a visual warning (aposematism) to birds, frogs, and spiders: "I\'m poisonous, don\'t eat me."\n\n🔹 **Hunting (in some species)**: Certain female fireflies (like those in the genus *Photuris*) mimic the flash patterns of other species to lure males in, then eat them. This is called aggressive mimicry.\n\n🔹 **Synchronization**: In some regions (like parts of Southeast Asia and the southeastern US), large groups of fireflies flash in unison. This likely makes males more visible to females and reduces confusion from overlapping signals.\n\n💡 **How it works**: The light comes from a chemical reaction in specialized cells in their abdomen. A molecule called **lu ...

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="qwen/qwen3.6-27b")
response = model.invoke("What is table in chinese called?")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **Question:** "What is table in chinese called?"\n   - **Key Entity:** "table" (furniture)\n   - **Target Language:** Chinese (Mandarin)\n\n2.  **Identify Core Translation:**\n   - The standard word for "table" in Chinese is 桌子 (zhuōzi).\n   - Breakdown: 桌 (zhuō) = table, 子 (zi) = noun suffix (diminutive/common for objects)\n   - Pinyin: zhuōzi\n   - Characters: 桌子\n\n3.  **Consider Context/Variations:**\n   - Are there other types of tables? Yes, but the general word is 桌子.\n   - Examples: \n     - Dining table: 餐桌 (cānzhuō)\n     - Desk: 书桌 (shūzhuō) or 办公桌 (bàngōngzhuō)\n     - Coffee table: 茶几 (chájī)\n   - But the direct, general translation is 桌子.\n\n4.  **Formulate Response:**\n   - Provide the direct translation with characters, pinyin, and pronunciation guide.\n   - Briefly mention common variants if helpful.\n   - Keep it clear and concise.\n\n   Draft:\n   The word for "table" in Chinese is **桌子** (pinyin: *zhuōzi*). \n   - 桌 (zhuō) means "table"\n   - 子 (zi) is a common suffix for everyday objects\n   Depending on the type of table, you might also hear:\n   - 餐桌 (cānzhuō) – dining table\n   - 书桌 (shūzhuō) – desk/study table\n   - 茶几 (chájī) – coffee table\n   Let me know if you need help with pronunciation or usage!\n\n5.  **Self-Correction/Verification:**\n   - Is 桌子 correct? Yes.\n   - Pinyin accurate? Yes, zhuōzi (first tone, neutral tone).\n   - Variants appropriate? Yes, commonly used.\n   - Tone/format clear? Yes.\n   - No extra fluff. Matches user query directly.\n\n   All good. Output matches response.✅\n</think>\n\nThe general word for "table" in Chinese is **桌子** (pinyin: *zhuōzi*).\n\n- **桌** (zhuō) = table\n- **子** (zi) = a common noun suffix for everyday objects\n\nDepending on the type of table, you\'ll often see more specific terms:\n- **餐桌** (cānzhuō) – dining table\n- **书桌** (shūzhuō) – desk / study table\n- **办公桌** (bàngōngzhuō) – office desk\n- **茶几** (chájī) – coffee table / tea table\n\nLet me know if you\'d like audio pronunciation tips or example sentences!', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 653, 'prompt_tokens': 17, 'total_tokens': 670, 'completion_time': 1.244014377, 'completion_tokens_details': None, 'prompt_time': 0.001178167, 'prompt_tokens_details': None, 'queue_time': 0.131167668, 'total_time': 1.245192544}, 'model_name': 'qwen/qwen3.6-27b', 'system_fingerprint': 'fp_3b9ee1e792', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0318b-dcbd-7b80-abae-ae5136a462fe-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 653, 'total_tokens': 670})

# %% [markdown]
# ### Streaming

# %%
model.invoke("Write me a 200 words paragraph on AI ")
# Out:
# AIMessage(content='\n<think>\nThinking Process:\n\n1.  **Deconstruct the Request:**\n    *   Topic: AI (Artificial Intelligence).\n    *   Length: Approximately 200 words.\n    *   Format: A single paragraph.\n\n2.  **Drafting - Attempt 1 (Mental or rough text generation):**\n    Artificial Intelligence, or AI, represents a transformative leap in technology, fundamentally reshaping how humans interact with the digital world. At its core, AI encompasses machine learning and deep learning algorithms that enable computers to analyze vast datasets, recognize patterns, and make decisions with minimal human intervention. From personalized recommendations on streaming platforms to sophisticated diagnostic tools in healthcare, AI\'s applications are ubiquitous and rapidly expanding. It drives efficiency in industries ranging from finance to manufacturing, automating repetitive tasks and unlocking insights previously inaccessible to human cognition. However, the rise of AI also sparks critical ethical debates regarding data privacy, algorithmic bias, and the potential displacement of jobs. As AI evolves, the focus shifts toward developing responsible frameworks that prioritize transparency and human oversight. Ultimately, AI is not merely a tool but a catalyst for innovation, promising to solve complex global challenges while demanding careful stewardship to ensure its benefits are equitably distributed and aligned with societal values.\n\n3.  **Word Count Check:**\n    *   "Artificial Intelligence, or AI, represents a transformative leap in technology, fundamentally reshaping how humans interact with the digital world." \n    *   "At its core, AI encompasses machine learning and deep learning algorithms that enable computers to analyze vast datasets, recognize patterns, and make decisions with minimal human intervention." \n    *   "From personalized recommendations on streaming platforms to sophisticated diagnostic tools in healthcare, AI\'s applications are ubiquitous and rapidly expanding." \n    *   "It drives efficiency in industries ranging from finance to manufacturing, automating repetitive tasks and unlocking insights previously inaccessible to human cognition." \n    *   "However, the rise of AI also sparks critical ethical debates regarding data privacy, algorithmic bias, and the potential displacement of jobs." \n    *   "As AI evolves, the focus shifts toward developing responsible frameworks that prioritize transparency and human oversight." \n    *   "Ultimately, AI is not merely a tool but a catalyst for innovation, promising to solve complex global challenges while demanding careful stewardship to ensure its benefits are equitably distributed and aligned with societal values." \n    *   *Total estimate:* 21+26+18+21+21+16+33 = 156 words.\n    *   *Result:* 156 words. This is too short. The user asked for 200 words. I need to expand.\n\n4.  **Expansion Strategy:**\n    *   Add more detail about generative AI.\n    *   Elaborate on the "paradigm shift" aspect.\n    *   Expand on the ethical implications or future outlook.\n    *   *Insertion points:*\n        *   After "minimal human intervention," add: "Generative AI, in particular, has revolutionized content creation, allowing machines to produce text, images, and code with startling creativity, blurring the lines between human and artificial output."\n        *   After "societal values," add: "Looking ahead, the integration of AI into everyday life will likely redefine education, governance, and creative expression, making collaboration between human ingenuity and artificial intelligence the defining characteristic of the modern era."\n\n5.  **Drafting - Attempt 2 (Incorporating expansions):**\n    Artificial Intelligence, or AI, represents a transformative leap in technology, fundamentally reshaping how humans interact with the digital world. At its core, AI encompasses machine learning and deep learning algorithms that enable computers to analyze vast datasets, rec ...

# %%
for chunk in model.stream("Write me a 200 words paragraph on PyTorch"):
    print(chunk.text, end="|", flush=True)
# Out:
# |
# <think>
# |Here|'s| a| thinking| process|:|
#
# |1|.| | **|An|alyze| User| Request|:**|
# |  | -| **|Topic|:**| Py|T|orch|
# |  | -| **|Length|:**| Exactly|/app|rox|imately| |2|0|0| words|
# |  | -| **|Format|:**| Single| paragraph|
#
# |2|.| | **|Ident|ify| Key| Points| about| Py|T|orch|:**|
# |  | -| Open|-source| machine| learning| framework|
# |  | -| Developed| by| Facebook| (|Meta|)| AI| Research| Lab|
# |  | -| Known| for| dynamic| computation| graphs| (|define|-by|-run|)|
# |  | -| Strong| support| for| deep| learning| research| and| production|
# |  | -| Python|ic|,| intuitive| API|
# |  | -| Wid|ely| adopted| in| academia| and| industry|
# |  | -| Features|:| aut|ograd|,| tensor| operations|,| distributed| training|,| Torch|Vision|,| Torch|Text|,| etc|.|
# |  | -| Comparison|/|position|ing|:| Alternative| to| TensorFlow|,| but| more| flexible| for| research|
#
# |3|.| | **|Draft| -| Mental| Writing| (|aim|ing| for| ~|2|0|0| words|):**|
# |  | Py|T|orch| is| an| open|-source| machine| learning| framework| developed| by| Meta|’s| AI| Research| Lab| that| has| become| a| cornerstone| of| modern| deep| learning| development|.| Built| on| a| Python|-first| philosophy|,| it| offers| an| intuitive|,| flexible| API| that| closely| mirrors| Num|Py|,| making| it| exceptionally| accessible| to| researchers| and| engineers| alike|.| Its| defining| feature| is| the| dynamic| computation| graph|,| which| allows| developers| to| define| and| modify| neural| network| architectures| on| the| fly| during| runtime|.| This| “|define|-by|-run|”| approach| simpl|ifies| debugging| and| acceler|ates| experimentation|,| particularly| for| complex| models| like| recurrent| or| transformer|-based| architectures|.| Py|T|orch| seamlessly| integrates| automatic| differentiation| through| its| Aut|ograd| engine|,| enabling| efficient| gradient| computation| without| manual| derivation|.| Beyond| research|,| the| framework| has| mature|d| into| a| robust| production| tool|,| supported| by| comprehensive| libraries| like| Torch|Vision|,| Torch|Text|,| and| Torch|Audio|,| as| well| as| deployment| solutions| such| as| Torch|Script| and| Torch|Serve|.| Its| active| community|,| extensive| documentation|,| and| strong| industry| adoption| have| cement|ed| Py|T|orch| as| a| leading| choice| for| both| academic| innovation| and| large|-scale| AI| applications|.| Whether| training| language| models|,| processing| computer| vision| tasks|,| or| prot|otyping| novel| algorithms|,| Py|T|orch| delivers| the| performance|,| scalability|,| and| developer| experience| needed| to| push| the| boundaries| of| artificial| intelligence|.|
#
# |4|.| | **|Word| Count| Check|:**|
# |  | Let|'s| count| the| words| in| the| draft|:|
# |  | Py|T|orch| (|1|)| is| (|2|)| an| (|3|)| open|-source| (|4|)| machine| (|5|)| learning| (|6|)| framework| (|7|)| developed| (|8|)| by| (|9|)| Meta|’s| (|1|0|)| AI| (|1|1|)| Research| (|1|2|)| Lab| (|1|3|)| that| (|1|4|)| has| (|1|5|)| become| (|1|6|)| a| (|1|7|)| cornerstone| (|1|8|)| of| (|1|9|)| modern| (|2|0|)| deep| (|2|1|)| learning| (|2|2|)| development|.| (|2|3|)| Built| (|2|4|)| on| (|2|5|)| a| (|2|6|)| Python|-first| (|2|7|)| philosophy|,| (|2|8|)| it| (|2|9|)| offers| (|3|0|)| an| (|3|1|)| intuitive|,| (|3|2|)| flexible| (|3|3|)| API| (|3|4|)| that| (|3|5|)| closely| (|3|6|)| mirrors| (|3|7|)| Num|Py|,| (|3|8|)| making| (|3|9|)| it| (|4|0|)| exceptionally| (|4|1|)| accessible| (|4|2|)| to| (|4|3|)| researchers| (|4|4|)| and| (|4|5|)| engineers| (|4|6|)| alike|.| (|4|7|)| Its| (|4|8|)| defining| (|4|9|)| feature| (|5|0|)| is| (|5|1|)| the| (|5|2|)| dynamic| (|5|3|)| computation| (|5|4|)| graph|,| (|5|5|)| which| (|5|6|)| allows| (|5|7|)| developers| (|5|8|)| to| (|5|9|)| define| (|6|0|)| and| (|6|1|)| modify| (|6|2|)| neural| (|6|3|)| network| (|6|4|)| architectures| (|6|5|)| on| (|6|6|)| the| (|6|7|)| fly| (|6|8|)| during| (|6|9|)| runtime|.| (|7|0|)| This| (|7|1|)| “|define|-by|-run|”| (|7|2|)| approach| (|7|3|)| simpl|ifies| (|7|4|)| debugging| (|7|5|)| and| (|7|6|)| acceler|ates| (|7|7|)| experimentation|,| (|7|8|)| particularly| (|7|9|)| for| (|8|0|)| complex| (|8|1|)| models| (|8|2|)| like| (|8|3|)| recurrent| (|8|4|)| or| (|8|5|)| transformer|-based| (|8|6|)| architectures|.| (|8|7|)| Py|T|orch| (|8|8|)| seamlessly| (|8|9|)| integrates| (|9|0|)| automatic| (|9|1|)| differentiation| (|9|2|)| through| (|9|3|)| its| (|9|4|)| Aut|ograd| (|9|5|)| engine|,| (|9|6|)| enabling| (|9|7|)| efficient| (|9|8|)| gradient| (|9|9|)| computation| (|1|0|0|)| without| (|1|0|1|)| manual| (|1|0|2|)| derivation|.| (|1|0|3|)| Beyond| (|1|0|4|)| research|,| (|1|0|5|)| the| (|1|0|6|)| framework| (|1|0|7|)| has| (|1|0|8|)| mature|d| (|1|0|9|)| into| (|1|1|0|)| a| (|1|1|1|)| robust| (|1|1|2|)| production| (|1|1|3|)| tool|,| (|1|1|4|)| supported| (|1|1|5|)| by| (|1|1|6|)| comprehensive| (|1|1|7|)| libraries| (|1|1|8|)| like| (|1|1|9|)| Torch|Vision|,| (|1|2|0|)| Torch|Text|,| (|1|2|1|)| and| (|1|2|2|)| Torch|Audio|,| (|1|2|3|)| as| (|1|2|4|)| well| (|1|2|5|)| as| (|1|2|6|)| deployment| (|1|2|7|)| solutions| (|1|2|8|)| such| (|1|2|9|)| as| (|1|3|0|)| Torch|Script| (|1|3|1|)| and| (|1|3|2|)| Torch|Serve|.| (|1|3|3|)| Its| (|1|3|4|)| active| (|1|3|5|)| community|,| (|1|3|6|)| extensive| (|1|3|7|)| documentation|,| (|1|3|8|)| and| (|1|3|9|)| strong| (|1|4|0|)| industry| (|1|4|1|)| adoption| (|1|4|2|)| have| (|1|4|3|)| cement|ed| (|1|4|4|)| Py|T|orch| (|1|4|5|)| as| (|1|4|6|)| a| (|1|4|7|)| leading| (|1|4|8|)| choice| (|1|4|9|)| for| (|1|5|0|)| both| (|1|5|1|)| academic| (|1|5|2|)| innovation| (|1|5|3|)| and| (|1|5|4|)| large|-scale| (|1|5|5|)| AI| (|1|5|6|)| applications|.| (|1|5|7|)| Whether| (|1|5|8|)| training| (|1|5|9|)| language| (|1|6|0|)| models|,| (|1|6|1|)| processing| (|1|6|2|)| computer| (|1|6|3|)| vision| (|1|6|4|)| tasks|,| (|1|6|5|)| or| (|1|6|6|)| prot|otyping| (|1|6|7|)| novel| (|1|6|8|)| algorithms|,| (|1|6|9|)| Py|T|orch| (|1|7|0|)| delivers| (|1|7|1|)| the| (|1|7|2|)| performance|,| (|1|7|3|)| scalability|,| (|1|7|4|)| and| (|1|7|5|)| developer| (|1|7|6|)| experience| (|1|7|7|)| needed| (|1|7|8|)| to| (|1|7|9|)| push| (|1|8|0|)| the| (|1|8|1|)| boundaries| (|1|8|2|)| of| (|1|8|3|)| artificial| (|1|8|4|)| intelligence|.| (|1|8|5|)|
#
# |  | Count| is| ~|1|8|5|.| Need| to| add| ~|1|5| words| to| hit| exactly| |2|0|0|,| or| adjust| to| be| closer| to| |2|0|0|.| Let|'s| count| carefully| and| adjust|.|
#
# |  | Let|'s| recount| properly|:|
# |  | Py|T|orch| is| an| open|-source| machine| learning| framework| developed| by| Meta|’s| AI| Research| Lab| that| has| become| a| cornerstone| of| modern| deep| learning| development|.| (|2|3|)|
# |  | Built| on| a| Python|-first| philosophy|,| it| offers| an| intuitive|,| flexible| API| that| closely| mirrors| Num|Py|,| making| it| exceptionally| accessible| to| researchers| and| engineers| alike|.| (|2|3|)|
# |  | Its| defining| feature| is| the| dynamic| computation| graph|,| which| allows| developers| to| define| and| modify| neural| network| architectures| on| the| fly| during| runtime|.| (|2|2|)|
# |  | This| “|define|-by|-run|”| approach| simpl|ifies| debugging| and| acceler|ates| experimentation|,| particularly| for| complex| models| like| recurrent| or| transformer|-based| architectures|.| (|1|7|)|
# |  | Py|T|orch| seamlessly| integrates| automatic| differentiation| through| its| Aut|ograd| engine|,| enabling| efficient| gradient| computation| without| manual| derivation|.| (|1|5|)|
# |  | Beyond| research|,| the| framework| has| mature|d| into| a| robust| production| tool|,| supported| by| comprehensive| libraries| like| Torch|Vision|,| Torch|Text|,| and| Torch|Audio|,| as| well| as| deployment| solutions| such| as| Torch|Script| and| Torch|Serve|.| (|2|9|)|
# |  | Its| active| community|,| extensive| documentation|,| and| strong| industry| adoption| have| cement|ed| Py|T|orch| as| a| leading| choice| for| both| academic| innovation| and| large|-scale| AI| applications|.| (|2|3|)|
# |  | Whether| training| language| models|,| processing| computer| vision| tasks|,| or| prot|otyping| novel| algorithms|,| Py|T|orch| delivers| the| performance|,| scalability|,| and| developer| experience| needed| to| push| the| boundaries| of| artificial| intelligence|.| (|2|7|)|
# |  | Total|:| |2|3|+|2|3|+|2|2|+|1|7|+|1|5|+|2|9|+|2|3|+|2|7| =| |1|7|9| words|.|
#
# |  | Need| ~|2|1| more| words|.| I|'ll| expand| slightly| on| ecosystem|/|impact| or| add| a| concluding| thought|.|
#
# |  | Let|'s| add|:| "|Its| seamless| GPU| acceleration| and| distributed| training| capabilities| further| empower| teams| to| scale| experiments| across| multi|-node| clusters| efficiently|."| (|1|8| words|)|
# |  | And| maybe| adjust| one| sentence| slightly| to| add| |3| more| words|.|
#
# |  | Let|'s| integrate| and| recount|:|
# |  | Py|T|orch| is| an| open|-source| machine| learning| framework| developed| by| Meta|’s| AI| Research| Lab| that| has| become| a| cornerstone| of| modern| deep| learning| development|.| Built| on| a| Python|-first| philosophy|,| it| offers| an| intuitive|,| flexible| API| that| closely| mirrors| Num|Py|,| making| it| exceptionally| accessible| to| researchers| and| engineers| alike|.| Its| defining| feature| is| the| dynamic| computation| graph|,| which| allows| developers| to| define| and| modify| neural| network| architectures| on| the| fly| during| runtime|.| This| “|define|-by|-run|”| approach| simpl|ifies| debugging|||
