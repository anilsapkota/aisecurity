# %%
import os 
from langchain.chat_models import init_chat_model

from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model = init_chat_model("groq:qwen/qwen3.6-27b")

# %%
model.invoke("Please tell me what is quantum interference")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query**: The user asks "Please tell me what is quantum interference". This is a straightforward request for an explanation of a fundamental concept in quantum mechanics.\n\n2.  **Identify Key Concepts**: \n   - Quantum interference\n   - Wave-particle duality\n   - Superposition\n   - Probability amplitudes\n   - Constructive/destructive interference\n   - Double-slit experiment (classic example)\n   - Applications (quantum computing, cryptography, etc.)\n   - Mathematical basis (wavefunctions, Born rule)\n\n3.  **Structure the Explanation**:\n   - Definition/Overview\n   - Core Principles (superposition, wave nature)\n   - How it works (probability amplitudes, constructive/destructive)\n   - Classic Example (double-slit experiment)\n   - Mathematical Insight (brief, accessible)\n   - Real-world Applications\n   - Common Misconceptions/Clarifications\n   - Summary\n\n4.  **Draft - Section by Section** 
# ...

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on AI")
]
response = model.invoke(messages)
response.content
# Out:
# '\n<think>\nHere\'s a thinking thinking sequence\n\n1.  **Deconstruct and Analyze the Request:**\n    *   Topic: AI (Artificial Intelligence).\n    *   Implicit/Explicit Goals: The user wants a poem about AI. Since no style, tone, or length was specified, I should aim for a balanced approach. A good poem on AI often explores themes like creation, consciousness, the relationship between human and machine, data, learning, and the future.\n\n2.  **Brainstorming Imagery and Metaphors:**\n    *   *Keywords:* Silicon, circuits, code, neural networks, dreams, electricity, data, mirror, echo, learning, infinite, cold, warm, human, creator, creation.\n    *   *Metaphors:*\n        *   AI as a mirror reflecting humanity.\n        *   AI as a child learning to walk/talk.\n        *   AI as a vast ocean of data.\n        *   AI as a weaver of words.\n        *   AI as a ghost in the machine.\n        *   *Selected Metaphors:* I like the idea of the "Mirror" and the "Weaver." The mirror reflects 
# ...

# %%
system_msg = SystemMessage("you are helpful coding assistant")

messages = [
    system_msg,
    HumanMessage("How do i create REST API with fastAPI")

]

response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Request:** The user wants to know how to create a REST API using FastAPI. This is a common, straightforward request that requires a clear, step-by-step guide with code examples.
#
# 2.  **Identify Key Components of FastAPI REST API:**
#    - Installation
#    - Basic setup (app creation, endpoints)
#    - Running the server
#    - Key features (path parameters, query parameters, request body, Pydantic models)
#    - Best practices/next steps
#
# 3.  **Structure the Response:**
#    - Prerequisites/Installation
#    - Minimal working example
#    - Step-by-step explanation
#    - Adding more features (Pydantic models, path/query parameters)
#    - Running & testing
#    - Next steps/resources
#    - Keep it concise but comprehensive
#
# 4.  **Draft - Section by Section:**
#
#    *Installation:*
#    ```bash
#    pip install fastapi uvicorn
#    ```
#
#    *Basic Example:*
#    ```python
#    from fastapi import FastAPI
#
# ...

# %%
#Detailed infor to the LLM through the System Message
system_msg = SystemMessage(""" 
You are a sensior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do i create a REST API?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Request:**
#    - **Question:** "How do i create a REST API?"
#    - **Context:** User is asking a broad question about creating a REST API.
#    - **My Role:** Senior Python developer with expertise in web frameworks.
#    - **Requirements:** Always provide code examples, explain reasoning, be concise but thorough.
#
# 2.  **Identify Key Concepts for REST API in Python:**
#    - REST principles (statelessness, resource-based, HTTP methods, status codes)
#    - Python web frameworks: FastAPI (modern, fast, auto-docs), Flask (lightweight, simple), Django REST Framework (batteries-included)
#    - I should recommend one as the primary example (FastAPI is currently best practice for new projects due to performance, type hints, and auto-generated docs), but mention alternatives briefly.
#    - Need to cover: setup, routing, request/response handling, running the server, testing.
#
# 3.  **Structure the Response:**
# ...

# %%
human_msg = HumanMessage(
    content="Hello!",
    name="alice", #optional to identify different users
    id="msg_123" #optional for tracing 
)

# %%
import os 
from langchain.chat_models import init_chat_model

from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
model = init_chat_model("gpt-4.1-mini")

# %%
response = model.invoke([
    human_msg
])
print(response.content)
# Out:
# Hello! How can I assist you today?

# %%
from langchain.messages import AIMessage,SystemMessage, HumanMessage
#Create an AI message manually (eg: for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

#Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,
    HumanMessage("Great! What is 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 equals 4.

# %%
response.usage_metadata
# Out:
# {'input_tokens': 48,
#  'output_tokens': 8,
#  'total_tokens': 56,
#  'input_token_details': {'audio': 0, 'cache_read': 0},
#  'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

ai_message = AIMessage(
    content= [],
    tool_calls =[{
        "name":"get_weather",
        "args":{"location":"Kathmandu"},
        "id":"call_123"
    }]
)

#execute tool and create result message
weather_result = "Sunny 72F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id = "call_123"
)


#Continue conversation
messages = [
    HumanMessage("What is the weather in Kathmandu?"),
    ai_message,
    tool_message,
]

response = model.invoke(messages)
print(response.content)
# Out:
# The weather in Kathmandu is currently sunny with a temperature of 72°F.

# %%
tool_message
# Out:
# ToolMessage(content='Sunny 72F', tool_call_id='call_123')
